# %% [markdown]
# # Midterm

# %% [markdown]
# Ok, we've reviewed a lot so far, so before we continue onto more specific kinds of analysis, using LLMs, and machine learning, complete this notebook that builds on the lessons in this series on pandas and EDA.

# %% [markdown]
# ___

# %% [markdown]
# ## Dataset
# ### *The Pudding*'s Film Dialogue Data

# %% [markdown]
# The dataset that we're working with in this lesson is taken from Hannah Andersen and Matt Daniels's *Pudding* essay, ["Film Dialogue from 2,000 screenplays, Broken Down by Gender and Age"](https://pudding.cool/2017/03/film-dialogue/). The dataset provides information about 2,000 films from 1925 to 2015, including characters’ names, genders, ages, how many words each character spoke in each film, the release year of each film, and how much money the film grossed. They included character gender information because they wanted to contribute data to a broader conversation about how "white men dominate movie roles."

# %% [markdown]
# ___

# %% [markdown]
# ## Import Pandas

# %%
import pandas as pd
pd.options.display.max_rows = 200

# %% [markdown]
# ## Import the Data

# %%
film_df = pd.read_csv('../data/Pudding/Pudding-Film-Dialogue-Clean.csv', delimiter=",", encoding='utf-8')

# %% [markdown]
# ## Overview
#
# To look at a random *n* number of rows in a DataFrame, we can use a method called `.sample()`.

# %%
film_df.sample(100)
# Out:
#                                        title  release_year        character  \
# 2472                      The Princess Bride          1987          Vizzini
# 11817             1492: Conquest of Paradise          1992   Captain Mendez
# 11192                                Tremors          1990   Heather Gummer
# 7817                                Invictus          2009   Linga Moonsamy
# 14616                               The Ring          2002            Aidan
# 3052                               Star Trek          2009            Sarek
# 20173                   Insidious: Chapter 2          2013   Dalton Lambert
# 22490                          Green Lantern          2011     Gala Partier
# 9281          The Nightmare Before Christmas          1993            Sally
# 21716                           Light of Day          1987    Bu Montgomery
# 8870                          Men in Black 3          2012  Prison Guard #1
# 19782                Jeff, Who Lives at Home          2011            Kevin
# 19819  Anchorman: The Legend of Ron Burgundy          2004   Frank Vitchard
# 53                             A Serious Man          2009     Mitch Brandt
# 10828                           Suspect Zero          2004    State Trooper
# 8813                              The Master          2012         Val Dodd
# 16139                          Lone Survivor          2013      Danny Dietz
# 2782                                Semi-Pro          2008         Clarence
# 14573                            Ratatouille          2007        Anton Ego
# 15746                                   Emma          1996    Harriet Smith
# 12224                                Cabaret          1972  Natalia Landaue
# 3529                        The Wizard of Oz          1939      Uncle Henry
# 17612                                 Zodiac          2007  Sgt. Jack Mulan
# 5928                             Deep Rising          1998          Hanover
# 9533                        Perfect Creature          2006           Freddy
# 1670                 Raiders of the Lost Ark          1981    Col. Musgrove
# 11645                The Wolf of Wall Street          2013  Teresa Petrillo
# 8939                                  Misery          1990           Buster
# 20269                        The Maze Runner          2014             Zart
# 2614                        The Replacements          2000      Shane Falco
# 6380             Even Cowgirls Get the Blues          1993      Miss Adrian
# 192                        American Gangster          2007            Tango
# 17032                     For Your Eyes Only          1981        Bibi Dahl
# 1005                               The Doors          1991           Gloria
# 16988                    Season of the Witch          2011  Cardinal D'Ambr
# 22128                        Southland Tales          2006  Hideo Takehashi
# 8414                      The Lincoln Lawyer          2011   Jesus Martinez
# 13676               The Last of the Mohicans          1992  Maj. Duncan Hey
# 417                                The Beach          2000          �Tienne
# 12637                  The Electric Horseman          1979       Fitzgerald
# 4223                          Apocalypse Now          1979   Mp Sergeant #1
# 8417                      The Lincoln Lawyer          2011     Louis Roulet
# 18814                          Capricorn One          1978  Charles Brubake
# 9733                                  Priest          2011        Lucy Pace
# 16704                            City of God          2002   Thiago - Tiago
# 11994                       Barney's Version          2010           Cedric
# 11266                               Twilight          2008    Edward Cullen
# 5613                              The Cooler          2003            Mikey
# 10817                             Surrogates          2009       Strickland
# 18333                                   Wild          2014            Bobbi
# 9525                                    Paul          2011      Moses Buggs
# 15400                         Twelve Monkeys          1995             Fale
# 13877                      The Magic Toyshop          1987     Uncle Philip
# 7382                                  Hesher          2010           Dustin
# 22227           A.I. Artificial Intelligence          2001         Dr. Know
# 20813             Born on the Fourth of July          1989  Infantry Colone
# 12991                       Reasonable Doubt          2014         Da Jones
# 17616                                 Zodiac          2007     Toschis Wife
# 10886                                Syriana          2005    Sydney Hewitt
# 18577                              El Dorado          1966             Bull
# 151                                      Ali          2001       Joe Smiley
# 4644                            The Believer          2001           Stuart
# 22544                             The Island          2005     James Mccord
# 7889                               Jane Eyre          2011      Grace Poole
# 13099                               Hardcore          1979     Jake Vandorn
# 19760                                 Harper          1966     Mrs. Sampson
# 3508                          The Wild Bunch          1969     Tector Gorch
# 3207                      Tall in the Saddle          1944          Rocklin
# 3911                       Alone in the Dark          2005            Krash
# 4070                            Analyze This          1999    Carlo Mangano
# 21950                            Primal Fear          1996         Woodside
# 10137                               Scream 3          2000    Sarah Darling
# 12433                          The Corruptor          1999      Louise Deng
# 910                               Deep Cover          1992  Young Russell S
# 11975             Back to the Future Part II          1989  Doctor Emmett B
# 7836                   It's a Wonderful Life          1946             Bert
# 994                             Dragonslayer          1981           Ulrich
# 14625                               The Ring          2002          Teacher
# 15219       Superman IV: The Quest for Peace          1987     Harry Howler
# 17140                             Grindhouse          2007  Wray (Segment "
# 21471                          Julius Caesar          1953         Lucilius
# 17652                           Street Kings          2008  Detective Paul
# 11630                             Wind Chill          2007  Snowplow Driver
# 19443                          Narrow Margin          1990           Nelson
# 2283               A Nightmare on Elm Street          1984         Dr. King
# 21870                          Transcendence          2014       Max Waters
# 15530                            The Village          2004     Kitty Walker
# 9829                           Rambling Rose          1991    Dr. Martinson
# 1774                                   Kafka          1991  Female Anarchis
# 9654                                 Platoon          1986             Rhah
# 9814                             Raging Bull          1980             Irma
# 10284                                Shampoo          1975        Anjanette
# 9002                        Moonrise Kingdom          2012          Redford
# 17120                      The Expendables 2          2012       Mr Lincoln
# 230                             Analyze That          2002    Anthony Bella
# 22679                    Monsters University          2013              Art
# 22372                     Dazed and Confused          1993             Carl
# 14338             O Brother, Where Art Thou?          2000   The Little Man
# 9282          The Nightmare Before Christmas          1993            Santa
# 22677                              Moneyball          2011  Umpire - Game 2
#
#       gender  words  proportion_of_dialogue   age  gross  script_id
# 2472     man   1160                0.105006  44.0   68.0       1246
# 11817    man    116                0.014245  36.0   15.0       3778
# 11192  woman    370                0.023053  35.0   34.0       3597
# 7817     man    288                0.039741   NaN   43.0       2632
# 14616    man    406                0.063957   NaN  193.0       4874
# 3052     man    267                0.036757  62.0  299.0       1361
# 20173    man    218                0.035110   NaN   89.0       7779
# 22490  woman    198                0.021694   NaN  128.0       8887
# 9281   woman    789                0.222567  39.0  157.0       3006
# 21716    man    786                0.110238  40.0   23.0       8453
# 8870     man    282                0.019497   NaN  195.0       2894
# 19782    man    124                0.021728  23.0    4.0       7624
# 19819    man    148                0.014697  33.0  117.0       7630
# 53       man    309                0.034223   NaN   10.0        633
# 10828    man    178                0.016120  43.0   12.0       3478
# 8813     man    133                0.009059  24.0   17.0       2866
# 16139    man    391                0.075981  28.0  133.0       5433
# 2782     man   1241                0.132713  33.0   40.0       1307
# 14573    man    644                0.077618  75.0  260.0       4853
# 15746  woman   1425                0.121184  24.0   43.0       5306
# 12224  woman    380                0.071228  25.0  219.0       3980
# 3529     man    148                0.015766  70.0  839.0       1483
# 17612    man    410                0.027975  46.0   41.0       6491
# 5928     man    719                0.140402  51.0   20.0       2139
# 9533     man    146                0.025431  48.0    NaN       3076
# 1670     man    135                0.030731  59.0    9.0       1034
# 11645  woman    150                0.008745  28.0  125.0       3737
# 8939     man   1044                0.104988  70.0  126.0       2930
# 20269    man    133                0.014264   NaN  108.0       7822
# 2614     man   1213                0.233404  36.0   72.0       1274
# 6380   woman   1084                0.047473  62.0    3.0       2243
# 192      man    140                0.015488  35.0  164.0        665
# 17032  woman    121                0.065512  23.0  194.0       6100
# 1005   woman    180                0.014308   NaN   72.0        871
# 16988    man    277                0.039119  89.0   27.0       6083
# 22128    man    915                0.089173  63.0    NaN       8634
# 8414     man    222                0.011419  35.0   63.0       2779
# 13676    man   1644                0.144147  24.0  151.0       4503
# 417      man    680                0.062911  27.0   64.0        726
# 12637    man    159                0.032076  46.0    NaN       4158
# 4223     man    164                0.007879   NaN   16.0       1676
# 8417     man   2257                0.116095  37.0   63.0       2779
# 18814    man   1739                0.172298  38.0    NaN       7179
# 9733   woman    522                0.041908  22.0   31.0       3135
# 16704    man    160                0.019091  18.0   11.0       5847
# 11994    man    115                0.010467   NaN    8.0       3892
# 11266    man   3680                0.256911  22.0  231.0       3621
# 5613     man    796                0.044896  28.0   11.0       2054
# 10817    man    156                0.012220  40.0   44.0       3476
# 18333  woman    477                0.048471  47.0   40.0       6907
# 9525     man    527                0.031064  48.0   41.0       3069
# 15400    man    382                0.034689  24.0  113.0       5160
# 13877    man    716                0.268870  54.0    NaN       4577
# 7382     man    312                0.032598  22.0    NaN       2535
# 22227    man    295                0.053490  50.0  120.0       8682
# 20813    man    107                0.017983  45.0  153.0       8025
# 12991    man    131                0.017945  50.0    NaN       4288
# 17616  woman    145                0.009894   NaN   41.0       6491
# 10886    man    978                0.056532  60.0   68.0       3492
# 18577    man   1264                0.108405  56.0   47.0       7075
# 151      man    128                0.014221  44.0   89.0        653
# 4644     man    362                0.021491   NaN    0.0       1805
# 22544    man    167                0.018691  48.0   48.0       8934
# 7889   woman    113                0.006830  43.0   12.0       2660
# 13099    man   2927                0.352269  52.0    NaN       4333
# 19760  woman    167                0.074025  42.0    NaN       7607
# 3508     man    379                0.042757  51.0    NaN       1475
# 3207     man   2241                0.245643  37.0    NaN       1394
# 3911   woman    130                0.018320   NaN    6.0       1609
# 4070     man    386                0.013384  53.0  183.0       1652
# 21950    man    254                0.018971   NaN  110.0       8559
# 10137  woman    852                0.055210  28.0  143.0       3285
# 12433  woman    400                0.041233  43.0   26.0       4044
# 910      man    207                0.026312   NaN   34.0        852
# 11975    man   2894                0.330177  51.0  258.0       3881
# 7836     man    278                0.020325  43.0    NaN       2642
# 994      man    676                0.109669  79.0   18.0        868
# 14625  woman    229                0.036074  34.0  193.0       4874
# 15219    man    118                0.017747  39.0   34.0       5076
# 17140    man   1545                0.243845  32.0   31.0       6140
# 21471    man    114                0.008622  56.0    NaN       8307
# 17652    man    972                0.100788  27.0   31.0       6512
# 11630    man    295                0.060414  50.0    NaN       3729
# 19443    man    479                0.102570  56.0   22.0       7441
# 2283     man    316                0.059398  34.0   68.0       1196
# 21870    man   2126                0.253911  43.0   24.0       8525
# 15530  woman    476                0.129842  29.0  159.0       5186
# 9829     man   1806                0.061038  49.0   12.0       3174
# 1774   woman    259                0.033432  33.0    2.0       1067
# 9654     man   1812                0.097787  23.0  323.0       3110
# 9814   woman    298                0.013275   NaN    NaN       3169
# 10284  woman    118                0.004767  30.0    NaN       3314
# 9002     man    203                0.024408   NaN   49.0       2947
# 17120    man    130                0.023132   NaN   92.0       6121
# 230      man    170                0.013238  43.0   48.0        678
# 22679    man    169                0.025567  37.0  286.0       9017
# 22372    man    198                0.019772  17.0   16.0       8809
# 14338    man    251                0.028646  37.0   73.0       4730
# 9282     man    200                0.056417   NaN  157.0       3006
# 22677    man    116                0.008418   NaN   82.0       9015

# %% [markdown]
# Generate information about all the columns in the data

# %%
film_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23047 entries, 0 to 23046
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   23047 non-null  object
#  1   release_year            23047 non-null  int64
#  2   character               23047 non-null  object
#  3   gender                  23047 non-null  object
#  4   words                   23047 non-null  int64
#  5   proportion_of_dialogue  23047 non-null  float64
#  6   age                     18262 non-null  float64
#  7   gross                   19386 non-null  float64
#  8   script_id               23047 non-null  int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 1.6+ MB

# %% [markdown]
# Just like Python has different data types, Pandas has different data types, too. These data types are automatically assigned to columns when we read in a CSV file. We can check these Pandas data types with the [`.dtypes` method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html).

# %% [markdown]
# | **Pandas Data Type** |  **Explanation**                                                                                   |
# |:-------------:|:---------------------------------------------------------------------------------------------------:|
# | `object`         | string                                                                               |
# | `float64`         | float                                               |
# | `int64`       | integer                                                        |
# | `datetime64`       |  date time

# %% [markdown]
# Make a histogram of the DataFrame

# %%
film_df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'release_year'}>,
#         <Axes: title={'center': 'words'}>],
#        [<Axes: title={'center': 'proportion_of_dialogue'}>,
#         <Axes: title={'center': 'age'}>],
#        [<Axes: title={'center': 'gross'}>,
#         <Axes: title={'center': 'script_id'}>]], dtype=object)

# %% [markdown]
# Generate descriptive statistics for all the columns in the data

# %%
film_df.describe(include='all')
# Out:
#             title  release_year character gender         words  \
# count       23047  23047.000000     23047  23047  23047.000000
# unique       1994           NaN     17543      3           NaN
# top     Lone Star           NaN    Doctor    man           NaN
# freq           40           NaN        37  16131           NaN
# mean          NaN   1998.132425       NaN    NaN    907.902634
# std           NaN     14.746052       NaN    NaN   1399.616135
# min           NaN   1929.000000       NaN    NaN    101.000000
# 25%           NaN   1992.000000       NaN    NaN    193.000000
# 50%           NaN   2001.000000       NaN    NaN    396.000000
# 75%           NaN   2009.000000       NaN    NaN    980.000000
# max           NaN   2015.000000       NaN    NaN  28102.000000
#
#         proportion_of_dialogue           age         gross     script_id
# count             23047.000000  18262.000000  19386.000000  23047.000000
# unique                     NaN           NaN           NaN           NaN
# top                        NaN           NaN           NaN           NaN
# freq                       NaN           NaN           NaN           NaN
# mean                  0.086518     42.275052    106.735428   4194.804486
# std                   0.107746     57.912595    145.861933   2473.037601
# min                   0.001537      3.000000      0.000000    280.000000
# 25%                   0.019773     30.000000     22.000000   2095.000000
# 50%                   0.042423     39.000000     56.000000   3694.000000
# 75%                   0.104171     50.000000    136.000000   6224.500000
# max                   0.923422   2009.000000   1798.000000   9254.000000

# %% [markdown]
# ### ❓ What patterns or outliers do you notice?
#
# Std release year is way lower than others. Min's age, gross, and script are way lower than others.

# %% [markdown]
# ## Drop Rows

# %%
film_df[film_df['age'] > 100]
# Out:
#                                 title  release_year        character gender  \
# 4024                  American Psycho          2000    Harold Carnes    man
# 5254                          Case 39          2009  Margaret Sulliv  woman
# 5370                            Chaos          2005     Bernie Callo    man
# 5950                     The Departed          2006          Realtor    man
# 6899                       Get Carter          2000          Thorpey    man
# 7787                    Into the Wild          2007             Bull    man
# 7968   Jay and Silent Bob Strike Back          2001  Silent Bob'S Mo  woman
# 9233                Never Been Kissed          1999      Monty Malik    man
# 9617                        The Piano          1993           Nessie  woman
# 9819                      Raging Bull          1980         Reporter    man
# 10151                           Se7en          1995    Officer Davis    man
# 13600                    Knight Moves          1992       Newscaster    man
# 14384                        Only You          1994  Himself       (    man
# 14757                          Scream          1996  Girl In Bathroo  woman
# 19221                      Borderland          2007  Captain Ramirez    man
# 21634               Last Man Standing          1996      Jack Mccool    man
#
#        words  proportion_of_dialogue     age  gross  script_id
# 4024     434                0.025271  2000.0   24.0       1639
# 5254     310                0.037944  2009.0   15.0       1962
# 5370     244                0.015051  2005.0    NaN       1985
# 5950     148                0.005575  2006.0  175.0       2144
# 6899     133                0.026552  2000.0   24.0       2380
# 7787     188                0.009936  2007.0   23.0       2625
# 7968     224                0.009292  2001.0   46.0       2673
# 9233     104                0.005219  1999.0   95.0       2986
# 9617     116                0.012262  1993.0   84.0       3095
# 9819     300                0.013364  1980.0    NaN       3169
# 10151    152                0.007366  1995.0  200.0       3288
# 13600    120                0.012451  1992.0    1.0       4487
# 14384    276                0.023730   102.0   41.0       4758
# 14757    162                0.018510  1996.0  202.0       4920
# 19221    121                0.017430  2007.0    NaN       7351
# 21634    338                0.044491  1996.0   35.0       8412

# %% [markdown]
# If you want to double check, you can examine the [data that the Pudding shared here](https://github.com/matthewfdaniels/scripts/blob/graphs/character_list5.csv) (you can control + F to search for specific characters).

# %%
film_df = film_df.drop(film_df[film_df['age'] > 100].index)

# %%
film_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23031 entries, 0 to 23046
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   23031 non-null  object
#  1   release_year            23031 non-null  int64
#  2   character               23031 non-null  object
#  3   gender                  23031 non-null  object
#  4   words                   23031 non-null  int64
#  5   proportion_of_dialogue  23031 non-null  float64
#  6   age                     18246 non-null  float64
#  7   gross                   19373 non-null  float64
#  8   script_id               23031 non-null  int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 1.8+ MB

# %%
film_df[film_df['age'] > 100]
# Out:
# Empty DataFrame
# Columns: [title, release_year, character, gender, words, proportion_of_dialogue, age, gross, script_id]
# Index: []

# %% [markdown]
# ## Rename Columns

# %%
film_df = film_df.rename(columns={'imdb_character_name': 'character', 'year': 'release_year'})

# %%
film_df.head()
# Out:
#                            title  release_year        character gender  words  \
# 0  The Bridges of Madison County          1995            Betty  woman    311
# 1  The Bridges of Madison County          1995  Carolyn Johnson  woman    873
# 2  The Bridges of Madison County          1995          Eleanor  woman    138
# 3  The Bridges of Madison County          1995  Francesca Johns  woman   2251
# 4  The Bridges of Madison County          1995            Madge  woman    190
#
#    proportion_of_dialogue   age  gross  script_id
# 0                0.048639  35.0  142.0        280
# 1                0.136534   NaN  142.0        280
# 2                0.021583   NaN  142.0        280
# 3                0.352049  46.0  142.0        280
# 4                0.029715  46.0  142.0        280

# %% [markdown]
# ## Filter

# %% [markdown]
# Find a specific film that you're intersted and then filter the DataFrame for only rows relevant to that film.
#
# If you want to search for films by decade and genre, you can [search the with the Pudding's handy data viz here](https://pudding.cool/2017/03/film-dialogue/embed.html).

# %%
film_df['title'] = 'twilight'

# %% [markdown]
# If you want to sort by characters who speak the most, feel free to add `.sort_values(by='words', ascending=False)`

# %%
film_df['gender']
# Out:
# 0        woman
# 1        woman
# 2        woman
# 3        woman
# 4        woman
#          ...
# 23042      man
# 23043      man
# 23044      man
# 23045    woman
# 23046    woman
# Name: gender, Length: 23031, dtype: object

# %% [markdown]
# Now pick a character from this film (or another character) and filter the DataFrame by character.

# %%
character_filter = ...

# %%
film_df[character_filter]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\whim_\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\whim_\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\whim_\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: Ellipsis
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\whim_\OneDrive\Documents\GitHub\3844f23-writing-digital-media\book\03-Pandas-Data-Analysis\MIDTERM.ipynb Cell 38 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/whim_/OneDrive/Documents/GitHub/3844f23-writing-digital-media/book/03-Pandas-Data-Analysis/MIDTERM.ipynb#X52sZmlsZQ%3D%3D?line=0'>1</a> film_df[character_filter]
#
# File c:\Users\whim_\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\Users\whim_\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: Ellipsis

# %% [markdown]
# ### ❓ How does this data align with your experience/knowledge of the film?
#
# Enter your response

# %% [markdown]
# ### ❓ How do these specific examples influence your thoughts about the data collection and categorization process? What would you have done differently (if anything)?
#
# Enter your response

# %% [markdown]
# ## Sort Values

# %% [markdown]
# Sort the DataFrame from the character who has the highest `proportion_of_dialogue` to the lowest.  Then examine the first 20 rows with `.head(20)` or `[:20]`.

# %%
film_df...

# %% [markdown]
# Sort the DataFrame from the character who has the lowest `proportion_of_dialogue` to the highest. Then examine the first 20 rows with `.head(20)` or `[:20]`.

# %%
film_df...

# %% [markdown]
# Sort the DataFrame from the character who speaks the least number of `words` to the character who speaks the most number of words. Then examine the first 20 rows with `.head(20)` or `[:20]`.

# %%
film_df...

# %% [markdown]
# ### ❓ What patterns do you notice here? What surprises you or doesn't surprise you?
#
# Enter your response

# %% [markdown]
# ## Groupby

# %% [markdown]
# Group by film and then calculate the sum total for every column.

# %%
film_df.groupby...

# %% [markdown]
# Group by film, isolate the `words` column, and then calculate the sum total for every column.

# %%
film_df.groupby...

# %% [markdown]
# Group by film AND gender, isolate the column `words`, and then calculate the sum total for every column.
#
# *Note: Remember that to group by multiple columns, you need to put the column names in square brackets `[]`.*

# %%
film_df.groupby...

# %% [markdown]
# ## Filter, Then Groupby

# %% [markdown]
# Filter the DataFrame for only characters labeled as `woman`

# %%
women_filter = film_df['gender'] == 'woman'

# %%
women_film_df = film_df[women_filter]

# %% [markdown]
# Filter the DataFrame for only characters labeled as `man`

# %%
men_filter = film_df['gender'] == 'man'

# %%
men_film_df = film_df[men_filter]

# %% [markdown]
# Now group `women_film_df` by film, isolate the `words` column, and sum the `words` spoken by women.

# %%
women_film_df.groupby('title')['words'].sum()
# Out:
# title
# (500) Days of Summer          5738
# 10 Things I Hate About You    8992
# 12 Years a Slave              3452
# 12 and Holding                5324
# 127 Hours                      809
#                               ...
# Zero Effect                   2216
# Zerophilia                    4612
# Zodiac                        1421
# eXistenZ                      3752
# xXx                            998
# Name: words, Length: 1940, dtype: int64

# %% [markdown]
# Assign this Series to a new variable `women_by_film`

# %%
women_by_film = women_film_df.groupby('title')['words'].sum()
women_by_film

# %% [markdown]
# Using the same construction, make a new another new variable `men_by_film`

# %%
men_by_film = men_film_df.groupby('title')['words'].sum()
men_by_film

# %% [markdown]
# Sort `women_by_film` from the film with the most words to the film with the least words. Then examine the top 20 values.

# %%
women_by_film.sort_values(ascending=False)[:20]

# %% [markdown]
# Assign this sorted list of movies to the variable `top20_women`

# %%
top20_women = women_by_film.sort_values(ascending=False)[:20]
top20_women

# %% [markdown]
# Using the same construction, make a new variable `top20_men`

# %%
top20_men = men_by_film.sort_values(ascending=False)[:20]
top20_men

# %% [markdown]
# ### ❓ What patterns do you notice here? What surprises you or doesn't surprise you?
#
# Enter your response

# %% [markdown]
# ## Saving Plots

# %% [markdown]
# Make a bar chart of `top20_women`. Give the chart a title, and specify a color.

# %%
top20_women.plot(
    kind='bar',
    # Add your code/parameters
)

# %% [markdown]
# To save the plot, you can use `ax.figure.savefig()` and the name of the file in quotation marks.

# %%
ax = top20_women.plot(
    kind='bar',
    # Add your code/parameters
)
ax.figure.savefig('./figures/top20_women.png')

# %% [markdown]
# Look in the file browser on the left and double click the PNG file. How does it look? Uh oh!
#
# Sometimes parts of a plot will get cut off when you save it. To fix this issue, you can use a function from the Matplotlib library called `plt.tight_layout()`, which will adjust the plot before you save it.
#
# To use this function, you need to `import matplotlib.pyplot as plt`.

# %%
import matplotlib.pyplot as plt

ax = top20_women.plot(kind='bar')
plt.tight_layout()
ax.figure.savefig('top20_women.png')

# %% [markdown]
# ## Scatter Plots and Line Plots

# %% [markdown]
# Let's make a scatter plot that shows how many words women and men speak based on their age.

# %%
women_film_df.groupby('age')['words'].sum().reset_index()

# %%
women_age_words = women_film_df.groupby('age')['words'].sum().reset_index()

# %%
men_age_words = men_film_df.groupby('age')['words'].sum().reset_index()

# %%
ax = women_age_words.plot(kind='scatter', x='age', y='words', color='red')
men_age_words.plot(ax=ax, kind='scatter', x='age', y='words', color='blue')

# %% [markdown]
# Now let's make a line plot of the exact same data. Copy and paste the code in the cell above and change it to produce a line plot instead of a scatter plot.

# %%
# Your code here
# Your code here

# %% [markdown]
# ## Reflection

# %% [markdown]
# Write about 250-500 words in response to each question below.

# %% [markdown]
# ### 1. Discuss your impressions of EDA techniques?

# %% [markdown]
# Enter your response

# %% [markdown]
# ### 2. What were some of the hurdles that you encountered moving through the EDA process?

# %% [markdown]
# Enter your response

# %% [markdown]
# ### 3. Explain why you chose some of the variables and questions to pursue. Also, what questions would you explore next, and why.

# %% [markdown]
# Enter your response
